# %% [markdown]
# <a href="https://colab.research.google.com/github/kazmi777999/first-pandas/blob/main/student_performance_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Student": [
        "Ali", "Sara", "John", "Emma", "Mike",
        "Sophia", "David", "Olivia", "Daniel", "Mia"
    ],

    "Major": [
        "CS", "Biology", "CS", "Business", "CS",
        "Biology", "Business", "CS", "Biology", "Business"
    ],

    "StudyHours": [
        10, 7, 4, 9, 6,
        8, 3, 12, 5, 10
    ],

    "Attendance": [
        95, 90, 75, 92, 85,
        94, 70, 98, 80, 96
    ],

    "SleepHours": [
        7, 8, 6, 7, 5,
        8, 6, 7, 7, 8
    ],

    "ExamScore": [
        92, 85, 68, 90, 78,
        88, 65, 97, 75, 93
    ]
}

def performance(score):
    if score >= 90:
        return "Excellent"
    elif score >= 80:
        return "Good"
    elif score >= 70:
        return "Average"
    else:
        return "Needs Improvement"

df = pd.DataFrame(data)

#df.sort_values("ExamScore",ascending = False).head(3)

#df[df["ExamScore"]<85]

#df [
    #(df["ExamScore"] > 85) &
    #(df["Attendance"] > 90) ]

#df ["ExamScore"].mean()
#df ["ExamScore"].min()
#df ["ExamScore"].max()

#df.groupby("Major")["StudyHours"].mean()


#df["Performance"] = df["ExamScore"].apply(performance)
#df[["Student", "ExamScore", "Performance"]]


#df[["StudyHours", "ExamScore"]].corr()

plt.scatter(
    df["Attendance"],
    df["ExamScore"]
)

plt.xlabel("Attendance")
plt.ylabel("Exam Score")
plt.title("Attendance vs Exam Score")

plt.show()

plt.scatter(
    df["Attendance"],
    df["ExamScore"]
)

plt.xlabel("Attendance")
plt.ylabel("Exam Score")
plt.title("Attendance vs Exam Score")

plt.show()
